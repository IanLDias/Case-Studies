# %%
import pandas as pd
import numpy as np
from glob import glob
import numbers

# %%
filenames = glob('Combined_*[a,b,c,d,e,f,g,h,i,j,k]*160c.dta')
list_dfs  = [pd.read_stata(f) for f in filenames]

# %%
list_dfs = [list_dfs[i].set_index('xwaveid') for i in range(11)]

# %%
list_males = [list_dfs[i][list_dfs[i].filter(regex='hgsex$').columns]for i in range(11)]

# %%
list_males = [list_dfs[i][list_males[i].iloc[:,0] == '[2] Female'] for i in range(11)]

# %%
pref1 = [list_males[i].filter(regex='jbhrcpr$') for i in range(11)]
pref2 = [list_males[i].filter(regex='jbhrcpr$') for i in range(11)]
pref2 = pref2[1:]

# %%
pref1[0]
# Out:
#                             ajbhrcpr
# xwaveid
# 0100002           [2] About the same
# 0100004           [2] About the same
# 0100005           [2] About the same
# 0100006  [-10] Non-responding person
# 0100007  [-10] Non-responding person
# ...                              ...
# 0119906  [-10] Non-responding person
# 0119907           [2] About the same
# 0119909  [-10] Non-responding person
# 0119910  [-10] Non-responding person
# 0119913  [-10] Non-responding person
#
# [10116 rows x 1 columns]

# %%
diff = [pref1[i].join(pref2[i]) for i in range(10)]
cleaned = [diff[i].dropna(how = 'any') for i in range(10)]

# %%
cleaned[0]
# Out:
#                             ajbhrcpr                     bjbhrcpr
# xwaveid
# 0100002           [2] About the same              [1] Fewer hours
# 0100004           [2] About the same           [2] About the same
# 0100005           [2] About the same           [2] About the same
# 0100006  [-10] Non-responding person               [-1] Not asked
# 0100007  [-10] Non-responding person  [-10] Non-responding person
# ...                              ...                          ...
# 0119901               [-1] Not asked               [-1] Not asked
# 0119907           [2] About the same               [-1] Not asked
# 0119909  [-10] Non-responding person  [-10] Non-responding person
# 0119910  [-10] Non-responding person  [-10] Non-responding person
# 0119913  [-10] Non-responding person              [1] Fewer hours
#
# [8764 rows x 2 columns]

# %%
t_minus_1 = [cleaned[i].iloc[:,0].value_counts() for i in range(10)]
t = [cleaned[i].iloc[:,1].value_counts() for i in range(10)]

# %%
clean_fewer = [cleaned[i][cleaned[i].iloc[:,0] == '[1] Fewer hours'] for i in range(10)]
clean_fewer = [clean_fewer[i].iloc[:,1].value_counts(normalize=True) for i in range(10)]

clean_current = [cleaned[i][cleaned[i].iloc[:,0] == '[2] About the same']for i in range(10)]
clean_current = [clean_current[i].iloc[:,1].value_counts(normalize=True) for i in range(10)]

clean_more = [cleaned[i][cleaned[i].iloc[:,0] == '[3] More hours'] for i in range(10)]
clean_more = [clean_more[i].iloc[:,1].value_counts(normalize=True) for i in range(10)]

# %%
clean_fewer = pd.DataFrame(clean_fewer)
clean_current = pd.DataFrame(clean_current)
clean_more  = pd.DataFrame(clean_more)

# %%
clean_unfin = clean_fewer.merge(clean_current, left_index=True, right_index=True)
clean_merged = clean_unfin.merge(clean_more, left_index=True, right_index=True)

# %%
clean_merged*100
# Out:
#           [-10] Non-responding person_x  [-1] Not asked_x  [-3] Dont know_x  \
# bjbhrcpr                       2.542373          8.474576          0.105932
# cjbhrcpr                       1.647059          8.352941          0.352941
# djbhrcpr                       1.280559          8.149010          0.116414
# ejbhrcpr                       1.021566          7.264472          0.113507
# fjbhrcpr                       0.521921          7.202505          0.000000
# gjbhrcpr                       1.215805          7.193516          0.000000
# hjbhrcpr                       0.595829          8.043694          0.099305
# ijbhrcpr                       0.522466          7.836991          0.104493
# jjbhrcpr                       0.540541          6.594595          0.108108
# kjbhrcpr                       0.720165          8.230453          0.000000
#
#           [-4] Refused/Not stated_x  [1] Fewer hours_x  [2] About the same_x  \
# bjbhrcpr                        NaN          48.305085             35.487288
# cjbhrcpr                        NaN          50.470588             34.000000
# djbhrcpr                        0.0          53.084983             33.294529
# ejbhrcpr                        NaN          54.597049             32.009081
# fjbhrcpr                        NaN          55.636743             34.446764
# gjbhrcpr                        0.0          54.204661             32.826748
# hjbhrcpr                        0.0          51.042701             36.842105
# ijbhrcpr                        0.0          52.246604             34.587252
# jjbhrcpr                        NaN          56.540541             32.756757
# kjbhrcpr                        0.0          53.086420             33.024691
#
#           [3] More hours_x  [-10] Non-responding person_y  [-1] Not asked_y  \
# bjbhrcpr          5.084746                       1.836735          9.897959
# cjbhrcpr          5.176471                       0.869565          8.593350
# djbhrcpr          4.074505                       1.293996          9.213251
# ejbhrcpr          4.994325                       0.962025          8.050633
# fjbhrcpr          2.192067                       0.718391          9.578544
# gjbhrcpr          4.559271                       0.825309          8.482348
# hjbhrcpr          3.376365                       0.925069          7.123034
# ijbhrcpr          4.702194                       0.695652          9.434783
# jjbhrcpr          3.459459                       0.686401          9.352209
# kjbhrcpr          4.938272                       0.771870          9.433962
#
#           [-3] Dont know_y  ...  [1] Fewer hours_y  [2] About the same_y  \
# bjbhrcpr          0.153061  ...          15.867347             62.091837
# cjbhrcpr          0.102302  ...          16.624041             63.938619
# djbhrcpr          0.000000  ...          17.184265             62.939959
# ejbhrcpr          0.050633  ...          18.126582             62.784810
# fjbhrcpr          0.000000  ...          15.469349             65.181992
# gjbhrcpr          0.091701  ...          17.469051             64.328290
# hjbhrcpr          0.046253  ...          15.957447             66.790009
# ijbhrcpr          0.173913  ...          14.391304             65.869565
# jjbhrcpr          0.000000  ...          14.929215             65.336765
# kjbhrcpr          0.042882  ...          14.322470             65.694683
#
#           [3] More hours_y  [-10] Non-responding person  [-1] Not asked  \
# bjbhrcpr         10.153061                     1.839465       13.879599
# cjbhrcpr          9.872123                     1.376936       14.285714
# djbhrcpr          9.368530                     1.565217       13.217391
# ejbhrcpr         10.025316                     0.729927       13.321168
# fjbhrcpr          9.051724                     1.803279       14.426230
# gjbhrcpr          8.757451                     1.073345       12.701252
# hjbhrcpr          9.158187                     1.590106       12.897527
# ijbhrcpr          9.434783                     0.720721       13.513514
# jjbhrcpr          9.695410                     1.155116       13.696370
# kjbhrcpr          9.691252                     1.230769       13.230769
#
#           [-3] Dont know  [-4] Refused/Not stated  [1] Fewer hours  \
# bjbhrcpr        0.000000                      NaN         8.026756
# cjbhrcpr        0.344234                      NaN         8.777969
# djbhrcpr        0.000000                      0.0         8.521739
# ejbhrcpr        0.000000                      NaN         8.576642
# fjbhrcpr        0.000000                      NaN        10.327869
# gjbhrcpr        0.000000                      0.0         6.618962
# hjbhrcpr        0.353357                      0.0         8.480565
# ijbhrcpr        0.000000                      0.0         6.486486
# jjbhrcpr        0.000000                      NaN         6.930693
# kjbhrcpr        0.000000                      0.0         6.461538
#
#           [2] About the same  [3] More hours
# bjbhrcpr           40.301003       35.953177
# cjbhrcpr           36.316695       38.898451
# djbhrcpr           37.391304       39.304348
# ejbhrcpr           41.605839       35.766423
# fjbhrcpr           39.836066       33.606557
# gjbhrcpr           42.933810       36.672630
# hjbhrcpr           41.166078       35.512367
# ijbhrcpr           41.621622       37.657658
# jjbhrcpr           39.273927       38.943894
# kjbhrcpr           36.307692       42.769231
#
# [10 rows x 21 columns]

# %%
unclean = clean_merged.mean(axis=0)
unclean = unclean*100

# %%
#_X = prefer to work fewer hours, _Y = current hours are good, _ = Prefer to work more hours

# %%
unclean = pd.DataFrame(unclean)

# %%
fewer_hrs = unclean[:7]
curr_hrs = unclean[7:14]
more_hrs = unclean[14:]

# %%
fewer_hrs.columns = ['Prefer to work fewer hours (t-1)']
curr_hrs.columns = ['Current hours are good (t-1)']
more_hrs.columns = ['Prefer to work more hours (t-1)']

# %%
fewer_hrs.index = more_hrs.index
curr_hrs.index = more_hrs.index

# %%
final_table = fewer_hrs.join(curr_hrs)
final_table = final_table.join(more_hrs)

# %%
final_table.sort_values('Prefer to work fewer hours (t-1)', ascending=False)
# Out:
#                              Prefer to work fewer hours (t-1)  \
# [1] Fewer hours                                     52.921537
# [2] About the same                                  33.927521
# [-1] Not asked                                       7.734275
# [3] More hours                                       4.255767
# [-10] Non-responding person                          1.060828
# [-3] Dont know                                       0.100070
# [-4] Refused/Not stated                              0.000000
#
#                              Current hours are good (t-1)  \
# [1] Fewer hours                                 16.034107
# [2] About the same                              64.495653
# [-1] Not asked                                   8.916007
# [3] More hours                                   9.520784
# [-10] Non-responding person                      0.958501
# [-3] Dont know                                   0.066075
# [-4] Refused/Not stated                          0.017746
#
#                              Prefer to work more hours (t-1)
# [1] Fewer hours                                     7.920922
# [2] About the same                                 39.675404
# [-1] Not asked                                     13.516953
# [3] More hours                                     37.508474
# [-10] Non-responding person                         1.308488
# [-3] Dont know                                      0.069759
# [-4] Refused/Not stated                             0.000000

# %% [markdown]
# Small extension: The above table is an average of ALL waves (t-1).

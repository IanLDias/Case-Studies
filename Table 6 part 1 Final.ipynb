# %%
import pandas as pd
import numpy as np
from glob import glob
import numbers

# %%
filenames = glob('Combined_*[a,b,c,d,e,f,g,h,i,j,k]*160c.dta')
list_dfs  = [pd.read_stata(f) for f in filenames]

# %%
list_dfs = [list_dfs[i].set_index('xwaveid') for i in range(11)]

# %%
list_males = [list_dfs[i][list_dfs[i].filter(regex='hgsex$').columns]for i in range(11)]

# %%
list_males = [list_dfs[i][list_males[i].iloc[:,0] == '[1] Male'] for i in range(11)]

# %%
pref1 = [list_males[i].filter(regex='jbhrcpr$') for i in range(11)]
pref2 = [list_males[i].filter(regex='jbhrcpr$') for i in range(11)]
pref2 = pref2[1:]

# %%
pref1[0]
# Out:
#                             ajbhrcpr
# xwaveid
# 0100001               [-1] Not asked
# 0100003           [2] About the same
# 0100008               [-1] Not asked
# 0100014              [1] Fewer hours
# 0100016           [2] About the same
# ...                              ...
# 0119903               [3] More hours
# 0119908           [2] About the same
# 0119911  [-10] Non-responding person
# 0119912           [2] About the same
# 0119914  [-10] Non-responding person
#
# [9798 rows x 1 columns]

# %%
diff = [pref1[i].join(pref2[i]) for i in range(10)]
cleaned = [diff[i].dropna(how = 'any') for i in range(10)]

# %%
t_minus_1 = [cleaned[i].iloc[:,0].value_counts() for i in range(10)]
t = [cleaned[i].iloc[:,1].value_counts() for i in range(10)]

# %%
clean_fewer = [cleaned[i][cleaned[i].iloc[:,0] == '[1] Fewer hours'] for i in range(10)]
clean_fewer = [clean_fewer[i].iloc[:,1].value_counts(normalize=True) for i in range(10)]

clean_current = [cleaned[i][cleaned[i].iloc[:,0] == '[2] About the same']for i in range(10)]
clean_current = [clean_current[i].iloc[:,1].value_counts(normalize=True) for i in range(10)]

clean_more = [cleaned[i][cleaned[i].iloc[:,0] == '[3] More hours'] for i in range(10)]
clean_more = [clean_more[i].iloc[:,1].value_counts(normalize=True) for i in range(10)]

# %%
clean_fewer = pd.DataFrame(clean_fewer)
clean_current = pd.DataFrame(clean_current)
clean_more  = pd.DataFrame(clean_more)

# %%
clean_unfin = clean_fewer.merge(clean_current, left_index=True, right_index=True)
clean_merged = clean_unfin.merge(clean_more, left_index=True, right_index=True)

# %%
clean_merged*100
# Out:
#           [-10] Non-responding person_x  [-1] Not asked_x  [-3] Dont know_x  \
# bjbhrcpr                       3.147700          4.439064          0.161421
# cjbhrcpr                       2.302632          4.687500          0.164474
# djbhrcpr                       2.289452          3.515944          0.163532
# ejbhrcpr                       0.918197          4.590985          0.000000
# fjbhrcpr                       0.838926          3.187919          0.000000
# gjbhrcpr                       1.411960          4.069767          0.000000
# hjbhrcpr                       1.198630          5.308219          0.000000
# ijbhrcpr                       0.790861          4.569420          0.087873
# jjbhrcpr                       1.354784          4.572396          0.000000
# kjbhrcpr                       1.526032          3.859964          0.000000
#
#           [-4] Refused/Not stated_x  [1] Fewer hours_x  [2] About the same_x  \
# bjbhrcpr                        NaN          58.595642             29.782082
# cjbhrcpr                        NaN          60.115132             29.523026
# djbhrcpr                        0.0          59.198692             31.316435
# ejbhrcpr                        NaN          58.180301             33.138564
# fjbhrcpr                        NaN          60.318792             32.718121
# gjbhrcpr                        0.0          57.641196             33.139535
# hjbhrcpr                        0.0          58.904110             31.250000
# ijbhrcpr                        0.0          57.029877             34.710018
# jjbhrcpr                        NaN          55.122777             34.970364
# kjbhrcpr                        0.0          55.565530             35.727110
#
#           [3] More hours_x  [-10] Non-responding person_y  [-1] Not asked_y  \
# bjbhrcpr          3.874092                       2.605119          6.078611
# cjbhrcpr          3.207237                       2.183199          4.983389
# djbhrcpr          3.515944                       3.064592          6.034889
# ejbhrcpr          3.171953                       2.148529          4.997665
# fjbhrcpr          2.936242                       1.262516          5.441881
# gjbhrcpr          3.737542                       1.648590          6.117137
# hjbhrcpr          3.339041                       1.470588          4.873950
# ijbhrcpr          2.811951                       1.062526          6.089089
# jjbhrcpr          3.979678                       1.724830          5.896510
# kjbhrcpr          3.321364                       1.005803          6.266925
#
#           [-3] Dont know_y  ...  [1] Fewer hours_y  [2] About the same_y  \
# bjbhrcpr          0.137112  ...          20.886654             61.517367
# cjbhrcpr          0.237304  ...          18.984338             65.685809
# djbhrcpr          0.141443  ...          18.057520             65.299387
# ejbhrcpr          0.140121  ...          18.122373             67.258291
# fjbhrcpr          0.000000  ...          17.762299             67.653461
# gjbhrcpr          0.130152  ...          17.440347             67.809111
# hjbhrcpr          0.084034  ...          15.924370             70.126050
# ijbhrcpr          0.000000  ...          16.877810             67.919902
# jjbhrcpr          0.080225  ...          14.560770             69.634978
# kjbhrcpr          0.000000  ...          15.125725             69.245648
#
#           [3] More hours_y  [-10] Non-responding person  [-1] Not asked  \
# bjbhrcpr          8.775137                     4.280822        8.732877
# cjbhrcpr          7.925961                     3.202847       11.032028
# djbhrcpr          7.355021                     2.879079       11.132438
# ejbhrcpr          7.333022                     1.202405       10.020040
# fjbhrcpr          7.879843                     0.782779       10.763209
# gjbhrcpr          6.854664                     1.565558        9.393346
# hjbhrcpr          7.521008                     0.851064        9.574468
# ijbhrcpr          8.050674                     1.422764       10.569106
# jjbhrcpr          8.102688                     1.232394       10.035211
# kjbhrcpr          8.355899                     1.607143       10.000000
#
#           [-3] Dont know  [-4] Refused/Not stated  [1] Fewer hours  \
# bjbhrcpr        0.000000                      NaN         9.417808
# cjbhrcpr        0.000000                      NaN        10.676157
# djbhrcpr        0.383877                      0.0         9.788868
# ejbhrcpr        0.000000                      NaN         8.817635
# fjbhrcpr        0.000000                      NaN         9.393346
# gjbhrcpr        0.000000                      0.0         7.436399
# hjbhrcpr        0.212766                      0.0         7.021277
# ijbhrcpr        0.000000                      0.0         6.097561
# jjbhrcpr        0.000000                      NaN         7.570423
# kjbhrcpr        0.000000                      0.0         5.357143
#
#           [2] About the same  [3] More hours
# bjbhrcpr           40.068493       37.500000
# cjbhrcpr           39.857651       35.231317
# djbhrcpr           38.387716       37.428023
# ejbhrcpr           40.681363       39.278557
# fjbhrcpr           41.878669       37.181996
# gjbhrcpr           46.575342       35.029354
# hjbhrcpr           45.957447       36.382979
# ijbhrcpr           36.178862       45.731707
# jjbhrcpr           41.901408       39.260563
# kjbhrcpr           41.964286       41.071429
#
# [10 rows x 21 columns]

# %%
unclean = clean_merged.mean(axis=0)
unclean = unclean*100

# %%
#_X = prefer to work fewer hours, _Y = current hours are good, _ = Prefer to work more hours

# %%
unclean = pd.DataFrame(unclean)

# %%
fewer_hrs = unclean[:7]
curr_hrs = unclean[7:14]
more_hrs = unclean[14:]

# %%
fewer_hrs.columns = ['Prefer to work fewer hours (t-1)']
curr_hrs.columns = ['Current hours are good (t-1)']
more_hrs.columns = ['Prefer to work more hours (t-1)']

# %%
fewer_hrs.index = more_hrs.index
curr_hrs.index = more_hrs.index

# %%
final_table = fewer_hrs.join(curr_hrs)
final_table = final_table.join(more_hrs)

# %%
final_table.sort_values('Prefer to work fewer hours (t-1)', ascending=False)
# Out:
#                              Prefer to work fewer hours (t-1)  \
# [1] Fewer hours                                     58.067205
# [2] About the same                                  32.627525
# [-1] Not asked                                       4.280118
# [3] More hours                                       3.389504
# [-10] Non-responding person                          1.577917
# [-3] Dont know                                       0.057730
# [-4] Refused/Not stated                              0.000000
#
#                              Current hours are good (t-1)  \
# [1] Fewer hours                                 17.374221
# [2] About the same                              67.215000
# [-1] Not asked                                   5.678004
# [3] More hours                                   7.815392
# [-10] Non-responding person                      1.817629
# [-3] Dont know                                   0.095039
# [-4] Refused/Not stated                          0.009430
#
#                              Prefer to work more hours (t-1)
# [1] Fewer hours                                     8.157662
# [2] About the same                                 41.345124
# [-1] Not asked                                     10.125272
# [3] More hours                                     38.409593
# [-10] Non-responding person                         1.902685
# [-3] Dont know                                      0.059664
# [-4] Refused/Not stated                             0.000000

# %% [markdown]
# Small extension: The above table is an average of ALL waves (t-1).
